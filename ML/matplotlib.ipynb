# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
from matplotlib.lines import lineStyles
import numpy as np
from mpl_toolkits.mplot3d.proj3d import rotation_about_vector

# %%
price = [48000, 54000, 57000, 49000,47000,45000]
year = [2015, 2016, 2017, 2018, 2019, 2020]
plt.plot(year, price)

# %%
batsman =pd.read_csv("/Users/abhishekwaghchaure/Desktop/Datasets/drive-download-20241216T035123Z-001/sharma-kohli.csv")

# %%
batsman
# Out:
#    index  RG Sharma  V Kohli
# 0   2008        404      165
# 1   2009        362      246
# 2   2010        404      307
# 3   2011        372      557
# 4   2012        433      364
# 5   2013        538      639
# 6   2014        390      359
# 7   2015        482      505
# 8   2016        489      973
# 9   2017        333      308

# %%
plt.plot(batsman['index'], batsman['V Kohli'])

# %%
plt.plot(batsman['index'], batsman['V Kohli'], label = 'virat')
plt.plot(batsman['index'], batsman['RG Sharma'], label = 'rohit')

# %%
plt.plot(batsman['index'], batsman['V Kohli'], label = 'virat', color = 'green')
plt.plot(batsman['index'], batsman['RG Sharma'], label = 'rohit', color = 'red')
plt.xlabel('Season')
plt.ylabel('Runs')
plt.title("Rohit vs Virat Carrer Complarison")
# Out:
# Text(0.5, 1.0, 'Rohit vs Virat Carrer Complarison')

# %%
plt.plot(batsman['index'], batsman['V Kohli'], label = 'virat', color = 'green', linestyle = 'solid', linewidth = 3)
plt.plot(batsman['index'], batsman['RG Sharma'], label = 'rohit', color = 'red', linestyle = 'dashdot', linewidth = 4)
plt.xlabel('Season')
plt.ylabel('Runs')
plt.title("Rohit vs Virat Carrer Complarison")
# Out:
# Text(0.5, 1.0, 'Rohit vs Virat Carrer Complarison')

# %%
plt.plot(batsman['index'], batsman['V Kohli'], label = 'virat', color = 'green', linestyle = 'solid', linewidth = 2, marker = 'd', markersize = 10)
plt.plot(batsman['index'], batsman['RG Sharma'], label = 'rohit', color = 'red', linestyle = 'dashdot', linewidth = 2, marker = 'o', markersize = 10)
plt.xlabel('Season')
plt.ylabel('Runs')
plt.title("Rohit vs Virat Carrer Complarison")
plt.legend(loc = 'best')

# %%
price = [48000, 54000, 57000, 49000, 47000, 45000, 450000]
year = [2015, 2016, 2017, 2018, 2019, 2020, 2021]
plt.plot(year, price)
plt.ylim(0,75000)
plt.xlim(2017,2019)
# Out:
# (2017.0, 2019.0)

# %%
plt.plot(batsman['index'], batsman['V Kohli'], label = 'virat', color = 'green', linestyle = 'solid', linewidth = 2, marker = 'd', markersize = 10)
plt.plot(batsman['index'], batsman['RG Sharma'], label = 'rohit', color = 'red', linestyle = 'dashdot', linewidth = 2, marker = '*', markersize = 10)
plt.xlabel('Season')
plt.ylabel('Runs')
plt.title("Rohit vs Virat Carrer Complarison")
plt.legend(loc = 'best')
plt.grid()
plt.show()

# %% [markdown]
# ## Scatter Plot
# #### Bivarate Analysis
# #### Numerical vs numerical althoigh we can hace categorial
# #### to find corelation

# %%
x = np.linspace(-10,10,50)
y = 10 * x + 3 + np.random.randint(0,300,50)

# %%
y
# Out:
# array([-36.        , 205.08163265, -24.83673469, -51.75510204,
#         26.32653061, 161.40816327,  71.48979592, 112.57142857,
#        143.65306122,  23.73469388, 161.81632653, 230.89795918,
#        165.97959184, -23.93877551,   3.14285714, 123.2244898 ,
#        176.30612245,  17.3877551 ,  99.46938776, 163.55102041,
#        232.63265306,  61.71428571,  15.79591837, 217.87755102,
#        232.95918367, 291.04081633, 255.12244898, 168.20408163,
#        165.28571429,  22.36734694, 124.44897959, 259.53061224,
#        178.6122449 , 112.69387755, 191.7755102 , 303.85714286,
#        284.93877551, 256.02040816,  98.10204082, 315.18367347,
#        351.26530612, 127.34693878, 169.42857143, 134.51020408,
#         97.59183673, 139.67346939, 277.75510204, 172.83673469,
#        175.91836735, 325.        ])

# %%
plt.scatter(x,y)

# %%
df = pd.read_csv("/Users/abhishekwaghchaure/Desktop/Datasets/drive-download-20241216T035123Z-001/batter.csv")
df = df.head(50)
df
# Out:
#             batter  runs        avg  strike_rate
# 0          V Kohli  6634  36.251366   125.977972
# 1         S Dhawan  6244  34.882682   122.840842
# 2        DA Warner  5883  41.429577   136.401577
# 3        RG Sharma  5881  30.314433   126.964594
# 4         SK Raina  5536  32.374269   132.535312
# 5   AB de Villiers  5181  39.853846   148.580442
# 6         CH Gayle  4997  39.658730   142.121729
# 7         MS Dhoni  4978  39.196850   130.931089
# 8       RV Uthappa  4954  27.522222   126.152279
# 9       KD Karthik  4377  26.852761   129.267572
# 10       G Gambhir  4217  31.007353   119.665153
# 11       AT Rayudu  4190  28.896552   124.148148
# 12       AM Rahane  4074  30.863636   117.575758
# 13        KL Rahul  3895  46.927711   132.799182
# 14       SR Watson  3880  30.793651   134.163209
# 15       MK Pandey  3657  29.731707   117.739858
# 16       SV Samson  3526  29.140496   132.407060
# 17      KA Pollard  3437  28.404959   140.457703
# ...

# %%
plt.scatter(df['avg'], df['strike_rate'], marker = '*', color = 'green')
plt.title('Avg vs Strike Rate Analysis')
plt.xlabel('Average')
plt.ylabel('Strike-Rate')
# Out:
# Text(0, 0.5, 'Strike-Rate')

# %%
tips = sns.load_dataset('tips')
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
plt.scatter(tips['total_bill'], tips['tip'], c = tips['size'])
plt.legend()
# Out:
# /var/folders/vt/hgv58_ws0rjfsg_1d8fcxgww0000gn/T/ipykernel_7423/3680079977.py:2: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend()

# %%
plt.plot(tips['total_bill'], tips['tip'], 'o')

# %% [markdown]
# ## Bar Chart
# #### categorical col and aggregate
# #### For both Bivarate and univarate analysis
# ####  Numerical vs Categorical

# %%
children=[10,20,30,10,20]
colors = ['red','blue', 'green', 'yellow', 'pink']

# %%
plt.bar(colors, children)
# Out:
# <BarContainer object of 5 artists>

# %%
plt.barh(colors, children)
# Out:
# <BarContainer object of 5 artists>

# %%
df = pd.read_csv('/Users/abhishekwaghchaure/Desktop/Datasets/drive-download-20241216T035123Z-001/batsman_season_record.csv')
df
# Out:
#           batsman  2015  2016  2017
# 0  AB de Villiers   513   687   216
# 1       DA Warner   562   848   641
# 2        MS Dhoni   372   284   290
# 3       RG Sharma   482   489   333
# 4         V Kohli   505   973   308

# %%
plt.bar(df['batsman'], df['2015'])
plt.bar(df['batsman'], df['2016'])
plt.bar(df['batsman'], df['2017'])
# Out:
# <BarContainer object of 5 artists>

# %%
plt.bar(df['batsman'], df['2015'], width=0.5)
# Out:
# <BarContainer object of 5 artists>

# %%
plt.bar(np.arange(df.shape[0]) - 0.2, df['2015'], width=0.2)
plt.bar(np.arange(df.shape[0]), df['2016'], width=0.2)
plt.bar(np.arange(df.shape[0]) + 0.2, df['2017'], width=0.2)
plt.xticks(np.arange(df.shape[0]), df['batsman'])
plt.show()

# %%
children = [10, 20, 30, 10, 20]
colors = ['red red red red red', 'blue blue blueblue blue', 'green green green green green green', 'yellow yellow yellow', 'pink pink']
plt.bar(colors, children)
plt.xticks(rotation = 40)
# Out:
# ([0, 1, 2, 3, 4],
#  [Text(0, 0, 'red red red red red'),
#   Text(1, 0, 'blue blue blueblue blue'),
#   Text(2, 0, 'green green green green green green'),
#   Text(3, 0, 'yellow yellow yellow'),
#   Text(4, 0, 'pink pink')])

# %% [markdown]
# ## Stack Bar Chart

# %%
plt.bar(df['batsman'],df['2017'], label = '2017')
plt.bar(df['batsman'],df['2016'], bottom = df['2017'], label = '2016')
plt.bar(df['batsman'],df['2015'], bottom = (df['2016'] + df['2017']), label = '2015')
plt.legend()
plt.show()

# %% [markdown]
# ## Histograms
# ### For numerical columns
# ### To check density functions
# ### Univarate Analysis

# %%
data = [32,45,56,10,15,27,61]

# %%
plt.hist(data, bins=[10,25,40,55,70])
plt.show()
