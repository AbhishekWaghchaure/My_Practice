# %% [markdown]
# ![image.png](attachment:image.png)

# %%
import torch
import torch.nn as nn

# %% [markdown]
# uses sigmoid and tan h activation functions

# %%
class LeNet(nn.Module):
    def __init__(self):
        super(LeNet,self).__init__()
        
        self.net = nn.Sequential(
            nn.Conv2d(in_channels=1, out_channels=6, kernel_size=(5,5),stride=(1,1),padding=(0,0)),
            nn.ReLU(),
            nn.AvgPool2d(kernel_size = (2,2), stride = (2,2)),
            
            nn.Conv2d(in_channels=6, out_channels=16, kernel_size=(5,5),stride=(1,1),padding=(0,0)),
            nn.ReLU(),
            nn.AvgPool2d(kernel_size=(2,2), stride=(2,2)),
            
            nn.Conv2d(in_channels=16, out_channels=120, kernel_size=(5,5),stride=(1,1),padding=(0,0)),
            nn.ReLU(),
            # nn.AvgPool2d(kernel_size=(2,2),stride=(2,2))
        )
        
        self.linear = nn.Sequential(
            nn.Linear(120,84),
            nn.Linear(84,10)
        )
        
    def forward(self,x):
        x = self.net(x)
        x = x.reshape(x.shape[0], -1)
        x = self.linear(x)
        return(x)

# %%
X = torch.randn(64,1,32,32)

# %%
model = LeNet()
print(model(X))
# Out:
# tensor([[ 0.0869,  0.0642, -0.0317,  0.1316,  0.0732, -0.1036, -0.0091,  0.0478,
#          -0.0362,  0.0585],
#         [ 0.0900,  0.0654, -0.0376,  0.1321,  0.0788, -0.0927, -0.0190,  0.0411,
#          -0.0389,  0.0611],
#         [ 0.0965,  0.0645, -0.0300,  0.1305,  0.0803, -0.1011, -0.0034,  0.0478,
#          -0.0391,  0.0604],
#         [ 0.0941,  0.0693, -0.0295,  0.1285,  0.0748, -0.1029, -0.0132,  0.0407,
#          -0.0347,  0.0562],
#         [ 0.0902,  0.0528, -0.0275,  0.1311,  0.0783, -0.1101, -0.0147,  0.0390,
#          -0.0347,  0.0564],
#         [ 0.0921,  0.0495, -0.0342,  0.1337,  0.0902, -0.0964, -0.0151,  0.0476,
#          -0.0395,  0.0565],
#         [ 0.0911,  0.0452, -0.0303,  0.1270,  0.0763, -0.1089, -0.0088,  0.0486,
#          -0.0297,  0.0605],
#         [ 0.0942,  0.0540, -0.0343,  0.1286,  0.0788, -0.1056, -0.0143,  0.0479,
#          -0.0408,  0.0492],
#         [ 0.0898,  0.0632, -0.0325,  0.1297,  0.0812, -0.0999, -0.0084,  0.0428,
#          -0.0348,  0.0561],
#         [ 0.0988,  0.0553, -0.0360,  0.1313,  0.0836, -0.0921, -0.0080,  0.0441,
#          -0.0441,  0.0549],
#         [ 0.0921,  0.0574, -0.0408,  0.1266,  0.0818, -0.0987, -0.0106,  0.0442,
#          -0.0401,  0.0615],
#         [ 0.0933,  0.0589, -0.0304,  0.1259,  0.0918, -0.1031, -0.0160,  0.0463,
#          -0.0321,  0.0535],
#         [ 0.0930,  0.0625, -0.0382,  0.1256,  0.0859, -0.0911, -0.0103,  0.0441,
#          -0.0386,  0.0512],
#         [ 0.0919,  0.0555, -0.0307,  0.1270,  0.0847, -0.1024, -0.0183,  0.0455,
#          -0.0370,  0.0622],
#         [ 0.0909,  0.0558, -0.0322,  0.1302,  0.0895, -0.1029, -0.0180,  0.0457,
#          -0.0391,  0.0529],
#         [ 0.0970,  0.0439, -0.0221,  0.1283,  0.0790, -0.0996, -0.0152,  0.0453,
#          -0.0386,  0.0541],
#         [ 0.0953,  0.0543, -0.0245,  0.1284,  0.0851, -0.1054, -0.0114,  0.0520,
#          -0.0344,  0.0572],
#         [ 0.0979,  0.0540, -0.0242,  0.1346,  0.0839, -0.0969, -0.0165,  0.0535,
#          -0.0365,  0.0594],
#         [ 0.0961,  0.0588, -0.0265,  0.1332,  0.0811, -0.1108, -0.0163,  0.0397,
#          -0.0451,  0.0521],
#         [ 0.0881,  0.0647, -0.0248,  0.1267,  0.0838, -0.1051, -0.0111,  0.0422,
#          -0.0368,  0.0547],
#         [ 0.0993,  0.0537, -0.0173,  0.1318,  0.0779, -0.1092, -0.0147,  0.0456,
#          -0.0332,  0.0618],
#         [ 0.0914,  0.0560, -0.0264,  0.1312,  0.0786, -0.1109, -0.0186,  0.0476,
#          -0.0395,  0.0583],
#         [ 0.1015,  0.0653, -0.0348,  0.1300,  0.0861, -0.1045, -0.0107,  0.0420,
#          -0.0364,  0.0571],
#         [ 0.0849,  0.0623, -0.0306,  0.1351,  0.0877, -0.0987, -0.0086,  0.0425,
#          -0.0379,  0.0605],
#         [ 0.1048,  0.0637, -0.0375,  0.1341,  0.0760, -0.1043, -0.0080,  0.0445,
#          -0.0393,  0.0582],
#         [ 0.0950,  0.0581, -0.0334,  0.1288,  0.0802, -0.0990, -0.0247,  0.0485,
#          -0.0394,  0.0604],
#         [ 0.1013,  0.0537, -0.0306,  0.1319,  0.0866, -0.1028, -0.0083,  0.0419,
#          -0.0406,  0.0509],
#         [ 0.0995,  0.0584, -0.0324,  0.1253,  0.0815, -0.1111, -0.0086,  0.0436,
#          -0.0327,  0.0588],
#         [ 0.0947,  0.0623, -0.0289,  0.1238,  0.0844, -0.1152, -0.0087,  0.0467,
#          -0.0357,  0.0551],
#         [ 0.0924,  0.0527, -0.0287,  0.1364,  0.0827, -0.0966, -0.0155,  0.0418,
#          -0.0500,  0.0554],
#         [ 0.0943,  0.0598, -0.0373,  0.1317,  0.0859, -0.0974, -0.0055,  0.0388,
#          -0.0403,  0.0627],
#         [ 0.0906,  0.0636, -0.0295,  0.1325,  0.0823, -0.1000, -0.0083,  0.0444,
#          -0.0443,  0.0531],
#         [ 0.0928,  0.0634, -0.0270,  0.1407,  0.0884, -0.1029, -0.0191,  0.0399,
#          -0.0417,  0.0530],
#         [ 0.0888,  0.0524, -0.0289,  0.1292,  0.0802, -0.1055, -0.0104,  0.0505,
#          -0.0410,  0.0536],
#         [ 0.0842,  0.0537, -0.0289,  0.1259,  0.0822, -0.1034, -0.0177,  0.0502,
#          -0.0394,  0.0560],
#         [ 0.0968,  0.0584, -0.0240,  0.1266,  0.0825, -0.0974, -0.0163,  0.0430,
#          -0.0417,  0.0575],
#         [ 0.0890,  0.0651, -0.0268,  0.1325,  0.0825, -0.0975, -0.0088,  0.0476,
#          -0.0330,  0.0551],
#         [ 0.0937,  0.0627, -0.0292,  0.1336,  0.0871, -0.0999, -0.0136,  0.0415,
#          -0.0324,  0.0543],
#         [ 0.1067,  0.0672, -0.0288,  0.1331,  0.0878, -0.1123, -0.0133,  0.0337,
#          -0.0392,  0.0529],
#         [ 0.0873,  0.0602, -0.0349,  0.1317,  0.0864, -0.1076, -0.0140,  0.0399,
#          -0.0327,  0.0538],
#         [ 0.0938,  0.0598, -0.0402,  0.1263,  0.0797, -0.1012, -0.0132,  0.0469,
#          -0.0325,  0.0557],
#         [ 0.1099,  0.0607, -0.0338,  0.1304,  0.0897, -0.0986, -0.0104,  0.0401,
#          -0.0338,  0.0536],
#         [ 0.0924,  0.0616, -0.0310,  0.1276,  0.0829, -0.0946, -0.0139,  0.0475,
#          -0.0344,  0.0587],
#         [ 0.0958,  0.0574, -0.0312,  0.1316,  0.0868, -0.0945, -0.0183,  0.0481,
#          -0.0403,  0.0659],
#         [ 0.0926,  0.0545, -0.0296,  0.1285,  0.0804, -0.1038, -0.0163,  0.0475,
#          -0.0441,  0.0517],
#         [ 0.1029,  0.0545, -0.0240,  0.1293,  0.0879, -0.0971, -0.0108,  0.0431,
#          -0.0320,  0.0580],
#         [ 0.0872,  0.0492, -0.0292,  0.1221,  0.0766, -0.1005, -0.0109,  0.0461,
#          -0.0433,  0.0540],
#         [ 0.0916,  0.0614, -0.0264,  0.1331,  0.0828, -0.1098, -0.0134,  0.0445,
#          -0.0375,  0.0605],
#         [ 0.0890,  0.0565, -0.0289,  0.1267,  0.0768, -0.0953, -0.0077,  0.0478,
#          -0.0406,  0.0537],
#         [ 0.0988,  0.0613, -0.0353,  0.1345,  0.0861, -0.0944, -0.0081,  0.0434,
#          -0.0380,  0.0563],
#         [ 0.0894,  0.0558, -0.0308,  0.1276,  0.0798, -0.0983, -0.0158,  0.0469,
#          -0.0427,  0.0605],
#         [ 0.0876,  0.0575, -0.0302,  0.1287,  0.0782, -0.0949, -0.0084,  0.0494,
#          -0.0460,  0.0568],
#         [ 0.0868,  0.0474, -0.0291,  0.1273,  0.0820, -0.1080, -0.0083,  0.0454,
#          -0.0419,  0.0559],
#         [ 0.0933,  0.0626, -0.0251,  0.1312,  0.0800, -0.0981, -0.0185,  0.0465,
#          -0.0356,  0.0645],
#         [ 0.0889,  0.0514, -0.0270,  0.1277,  0.0729, -0.0883, -0.0005,  0.0524,
#          -0.0411,  0.0525],
#         [ 0.0941,  0.0660, -0.0350,  0.1350,  0.0865, -0.1007, -0.0203,  0.0421,
#          -0.0340,  0.0634],
#         [ 0.0982,  0.0530, -0.0172,  0.1327,  0.0915, -0.1121, -0.0116,  0.0391,
#          -0.0427,  0.0567],
#         [ 0.0866,  0.0613, -0.0305,  0.1245,  0.0853, -0.1104, -0.0245,  0.0463,
#          -0.0303,  0.0659],
#         [ 0.0927,  0.0574, -0.0322,  0.1226,  0.0843, -0.1065, -0.0132,  0.0448,
#          -0.0294,  0.0492],
#         [ 0.0946,  0.0651, -0.0307,  0.1307,  0.0833, -0.0994, -0.0156,  0.0459,
#          -0.0361,  0.0646],
#         [ 0.0961,  0.0591, -0.0263,  0.1295,  0.0865, -0.1026, -0.0093,  0.0472,
#          -0.0313,  0.0574],
#         [ 0.0880,  0.0549, -0.0399,  0.1293,  0.0823, -0.0944, -0.0198,  0.0474,
#          -0.0468,  0.0553],
#         [ 0.0889,  0.0525, -0.0360,  0.1284,  0.0799, -0.1176, -0.0084,  0.0420,
#          -0.0372,  0.0612],
#         [ 0.0924,  0.0607, -0.0311,  0.1243,  0.0878, -0.0987, -0.0172,  0.0461,
#          -0.0428,  0.0523]], grad_fn=<AddmmBackward0>)
