# %%
squireels_by_park = {'Madison Square Park': [{'primary_fur_color': 'Gray',
   'highlights_in_fur_color': None,
   'activities': 'Foraging',
   'interactions_with_humans': 'Indifferent'},
  {'primary_fur_color': 'Gray',
   'highlights_in_fur_color': None,
   'activities': 'Sitting',
   'interactions_with_humans': 'Indifferent'}],
 'Tompkins Square Park': [{'primary_fur_color': 'Gray',
   'highlights_in_fur_color': 'Gray',
   'activities': 'Foraging',
   'interactions_with_humans': 'Approaches'},
  {'primary_fur_color': 'Gray',
   'highlights_in_fur_color': 'Gray',
   'activities': 'Climbing (down tree)',
   'interactions_with_humans': 'Indifferent'},
  {'primary_fur_color': 'Gray',
   'highlights_in_fur_color': 'Gray',
   'activities': 'Foraging',
   'interactions_with_humans': 'Indifferent'},
  {'primary_fur_color': 'Gray',
   'highlights_in_fur_color': 'Gray',
   'activities': 'Foraging',
   'interactions_with_humans': 'Indifferent'}],
 'Union Square Park': [{'primary_fur_color': 'Gray',
   'highlights_in_fur_color': None,
   'activities': 'Eating, Foraging',
   'interactions_with_humans': None},
  {'primary_fur_color': 'Cinnamon',
   'highlights_in_fur_color': None,
   'activities': 'Foraging',
   'interactions_with_humans': None},
  {'primary_fur_color': 'Gray',
   'highlights_in_fur_color': None,
   'activities': 'Eating, Foraging',
   'interactions_with_humans': None},
  {'primary_fur_color': 'Gray',
   'highlights_in_fur_color': None,
   'activities': 'Digging',
   'interactions_with_humans': 'Indifferent'}]}

# %%
print(squireels_by_park.values())
print(squireels_by_park.keys())
# Out:
# dict_values([[{'primary_fur_color': 'Gray', 'highlights_in_fur_color': None, 'activities': 'Foraging', 'interactions_with_humans': 'Indifferent'}, {'primary_fur_color': 'Gray', 'highlights_in_fur_color': None, 'activities': 'Sitting', 'interactions_with_humans': 'Indifferent'}], [{'primary_fur_color': 'Gray', 'highlights_in_fur_color': 'Gray', 'activities': 'Foraging', 'interactions_with_humans': 'Approaches'}, {'primary_fur_color': 'Gray', 'highlights_in_fur_color': 'Gray', 'activities': 'Climbing (down tree)', 'interactions_with_humans': 'Indifferent'}, {'primary_fur_color': 'Gray', 'highlights_in_fur_color': 'Gray', 'activities': 'Foraging', 'interactions_with_humans': 'Indifferent'}, {'primary_fur_color': 'Gray', 'highlights_in_fur_color': 'Gray', 'activities': 'Foraging', 'interactions_with_humans': 'Indifferent'}], [{'primary_fur_color': 'Gray', 'highlights_in_fur_color': None, 'activities': 'Eating, Foraging', 'interactions_with_humans': None}, {'primary_fur_color': 'Cinnamon'
# ...

# %%
for key , value in squireels_by_park.items():
    print(key,value)
# Out:
# Madison Square Park [{'primary_fur_color': 'Gray', 'highlights_in_fur_color': None, 'activities': 'Foraging', 'interactions_with_humans': 'Indifferent'}, {'primary_fur_color': 'Gray', 'highlights_in_fur_color': None, 'activities': 'Sitting', 'interactions_with_humans': 'Indifferent'}]
# Tompkins Square Park [{'primary_fur_color': 'Gray', 'highlights_in_fur_color': 'Gray', 'activities': 'Foraging', 'interactions_with_humans': 'Approaches'}, {'primary_fur_color': 'Gray', 'highlights_in_fur_color': 'Gray', 'activities': 'Climbing (down tree)', 'interactions_with_humans': 'Indifferent'}, {'primary_fur_color': 'Gray', 'highlights_in_fur_color': 'Gray', 'activities': 'Foraging', 'interactions_with_humans': 'Indifferent'}, {'primary_fur_color': 'Gray', 'highlights_in_fur_color': 'Gray', 'activities': 'Foraging', 'interactions_with_humans': 'Indifferent'}]
# ...

# %%
for i in squireels_by_park.items():
    print(i)
# Out:
# ('Madison Square Park', [{'primary_fur_color': 'Gray', 'highlights_in_fur_color': None, 'activities': 'Foraging', 'interactions_with_humans': 'Indifferent'}, {'primary_fur_color': 'Gray', 'highlights_in_fur_color': None, 'activities': 'Sitting', 'interactions_with_humans': 'Indifferent'}])
# ('Tompkins Square Park', [{'primary_fur_color': 'Gray', 'highlights_in_fur_color': 'Gray', 'activities': 'Foraging', 'interactions_with_humans': 'Approaches'}, {'primary_fur_color': 'Gray', 'highlights_in_fur_color': 'Gray', 'activities': 'Climbing (down tree)', 'interactions_with_humans': 'Indifferent'}, {'primary_fur_color': 'Gray', 'highlights_in_fur_color': 'Gray', 'activities': 'Foraging', 'interactions_with_humans': 'Indifferent'}, {'primary_fur_color': 'Gray', 'highlights_in_fur_color': 'Gray', 'activities': 'Foraging', 'interactions_with_humans': 'Indifferent'}])
# ...

# %%
squireels_by_park['Madison Square Park'].get('primary_fur_color', 'N/A')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[41], line 1
# ----> 1 squireels_by_park['Madison Square Park'].get('primary_fur_color', 'N/A')
#
# AttributeError: 'list' object has no attribute 'get'

# %%
squireels_by_park[1].get('primary_fur_color')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[24], line 1
# ----> 1 squireels_by_park[1].get('primary_fur_color')
#
# KeyError: 1

# %%
squireel_Union_park = squireels_by_park.pop('Union Square Park', {})

# %%
squireel_Union_park
# Out:
# [{'primary_fur_color': 'Gray',
#   'highlights_in_fur_color': None,
#   'activities': 'Eating, Foraging',
#   'interactions_with_humans': None},
#  {'primary_fur_color': 'Cinnamon',
#   'highlights_in_fur_color': None,
#   'activities': 'Foraging',
#   'interactions_with_humans': None},
#  {'primary_fur_color': 'Gray',
#   'highlights_in_fur_color': None,
#   'activities': 'Eating, Foraging',
#   'interactions_with_humans': None},
#  {'primary_fur_color': 'Gray',
#   'highlights_in_fur_color': None,
#   'activities': 'Digging',
#   'interactions_with_humans': 'Indifferent'}]

# %%
for i in squireels_by_park:
    print (i)
# Out:
# Madison Square Park
# Tompkins Square Park

# %%
squireels_by_park.keys()
# Out:
# dict_keys(['Madison Square Park', 'Tompkins Square Park'])

# %%
for park_name in squireels_by_park:
    # Safely print a list of the primary_fur_color for each squirrel in park_name
    print(park_name, [squirrel.get('primary_fur_color', 'N/A') for squirrel in squireels_by_park[park_name]])
# Out:
# Madison Square Park ['Gray', 'Gray']
# Tompkins Square Park ['Gray', 'Gray', 'Gray', 'Gray']
# Union Square Park ['Gray', 'Cinnamon', 'Gray', 'Gray']

# %%
squireels_by_park.get('Madison Square Park')
# Out:
# [{'primary_fur_color': 'Gray',
#   'highlights_in_fur_color': None,
#   'activities': 'Foraging',
#   'interactions_with_humans': 'Indifferent'},
#  {'primary_fur_color': 'Gray',
#   'highlights_in_fur_color': None,
#   'activities': 'Sitting',
#   'interactions_with_humans': 'Indifferent'}]

# %%
for i in squireels_by_park['Madison Square Park']:
    print(i.get('activites'))
# Out:
# None
# None

# %%
squireel_Union_park
# Out:
# [{'primary_fur_color': 'Gray',
#   'highlights_in_fur_color': None,
#   'activities': 'Eating, Foraging',
#   'interactions_with_humans': None},
#  {'primary_fur_color': 'Cinnamon',
#   'highlights_in_fur_color': None,
#   'activities': 'Foraging',
#   'interactions_with_humans': None},
#  {'primary_fur_color': 'Gray',
#   'highlights_in_fur_color': None,
#   'activities': 'Eating, Foraging',
#   'interactions_with_humans': None},
#  {'primary_fur_color': 'Gray',
#   'highlights_in_fur_color': None,
#   'activities': 'Digging',
#   'interactions_with_humans': 'Indifferent'}]

# %%
[i for i in squireel_Union_park if i['primary_fur_color'] == 'Cinnamon']
# Out:
# [{'primary_fur_color': 'Cinnamon',
#   'highlights_in_fur_color': None,
#   'activities': 'Foraging',
#   'interactions_with_humans': None}]

# %%
for i in squireels_by_park ['Tompkins Square Park']:
    print(i['activities'])
# Out:
# Foraging
# Climbing (down tree)
# Foraging
# Foraging

# %%
squireels_by_park
# Out:
# {'Madison Square Park': [{'primary_fur_color': 'Gray',
#    'highlights_in_fur_color': None,
#    'activities': 'Foraging',
#    'interactions_with_humans': 'Indifferent'},
#   {'primary_fur_color': 'Gray',
#    'highlights_in_fur_color': None,
#    'activities': 'Sitting',
#    'interactions_with_humans': 'Indifferent'}],
#  'Tompkins Square Park': [{'primary_fur_color': 'Gray',
#    'highlights_in_fur_color': 'Gray',
#    'activities': 'Foraging',
#    'interactions_with_humans': 'Approaches'},
#   {'primary_fur_color': 'Gray',
#    'highlights_in_fur_color': 'Gray',
#    'activities': 'Climbing (down tree)',
#    'interactions_with_humans': 'Indifferent'},
#   {'primary_fur_color': 'Gray',
#    'highlights_in_fur_color': 'Gray',
#    'activities': 'Foraging',
#    'interactions_with_humans': 'Indifferent'},
#   {'primary_fur_color': 'Gray',
#    'highlights_in_fur_color': 'Gray',
#    'activities': 'Foraging',
#    'interactions_with_humans': 'Indifferent'}],
# ...

# %%
squireels_by_park.get("Madison Square Park")
# Out:
# [{'primary_fur_color': 'Gray',
#   'highlights_in_fur_color': None,
#   'activities': 'Foraging',
#   'interactions_with_humans': 'Indifferent'},
#  {'primary_fur_color': 'Gray',
#   'highlights_in_fur_color': None,
#   'activities': 'Sitting',
#   'interactions_with_humans': 'Indifferent'}]

# %%
squireels_by_park['Madison Square Park']
# Out:
# [{'primary_fur_color': 'Gray',
#   'highlights_in_fur_color': None,
#   'activities': 'Foraging',
#   'interactions_with_humans': 'Indifferent'},
#  {'primary_fur_color': 'Gray',
#   'highlights_in_fur_color': None,
#   'activities': 'Sitting',
#   'interactions_with_humans': 'Indifferent'}]

# %%
squireels_by_park.items()
# Out:
# dict_items([('Madison Square Park', [{'primary_fur_color': 'Gray', 'highlights_in_fur_color': None, 'activities': 'Foraging', 'interactions_with_humans': 'Indifferent'}, {'primary_fur_color': 'Gray', 'highlights_in_fur_color': None, 'activities': 'Sitting', 'interactions_with_humans': 'Indifferent'}]), ('Tompkins Square Park', [{'primary_fur_color': 'Gray', 'highlights_in_fur_color': 'Gray', 'activities': 'Foraging', 'interactions_with_humans': 'Approaches'}, {'primary_fur_color': 'Gray', 'highlights_in_fur_color': 'Gray', 'activities': 'Climbing (down tree)', 'interactions_with_humans': 'Indifferent'}, {'primary_fur_color': 'Gray', 'highlights_in_fur_color': 'Gray', 'activities': 'Foraging', 'interactions_with_humans': 'Indifferent'}, {'primary_fur_color': 'Gray', 'highlights_in_fur_color': 'Gray', 'activities': 'Foraging', 'interactions_with_humans': 'Indifferent'}]), ('Union Square Park', [{'primary_fur_color': 'Gray', 'highlights_in_fur_color': None, 'activities': 'Eating, Foragi
# ...

# %%
import random

# Create a large set with unique random numbers
large_random_set = set()

# Add random numbers to the set until it reaches the desired size
while len(large_random_set) < 1000000:
    large_random_set.add(random.randint(0, 2000000))

# Verify the size of the set
print(len(large_random_set))  # Output: 1000000
# Out:
# 1000000

# %%
large_random_set
# Out:
# {2,
#  5,
#  8,
#  11,
#  12,
#  13,
#  17,
#  18,
#  21,
#  24,
#  28,
#  29,
#  32,
#  34,
#  38,
#  39,
#  41,
#  43,
#  45,
#  48,
#  50,
#  51,
#  53,
#  54,
#  55,
#  59,
#  60,
#  63,
#  64,
#  66,
#  73,
#  75,
#  77,
#  78,
#  80,
#  83,
#  86,
#  87,
#  88,
#  98,
#  99,
#  101,
#  103,
#  105,
#  108,
#  109,
#  110,
#  111,
#  112,
#  114,
#  115,
#  117,
#  118,
#  121,
#  122,
#  123,
#  125,
#  131,
#  133,
#  141,
#  143,
#  144,
#  146,
#  147,
#  148,
#  153,
#  154,
#  155,
#  156,
#  157,
#  158,
#  166,
#  167,
#  168,
#  169,
#  170,
#  171,
#  172,
#  173,
#  177,
#  178,
#  181,
#  183,
#  184,
#  189,
#  191,
#  199,
#  204,
#  206,
#  207,
#  213,
#  216,
#  221,
#  223,
#  224,
#  225,
#  227,
#  228,
#  230,
#  232,
#  233,
#  236,
#  238,
#  239,
#  240,
#  242,
#  243,
#  245,
#  246,
#  248,
#  249,
#  250,
#  251,
#  253,
#  254,
#  256,
#  257,
#  258,
#  259,
#  260,
#  261,
#  265,
#  266,
#  268,
#  269,
#  270,
#  274,
#  276,
#  277,
#  278,
# ...

# %%
large_random_set.add(33
                     )

# %%
len(large_random_set)
# Out:
# 1000001

# %%
large_random_set.update({23,34,55})

# %%
len(large_random_set)
# Out:
# 1000002

# %%
large_random_set.discard({23,34,55})

# %%
large_random_set.pop()
# Out:
# 2

# %%
large_random_set.pop()
# Out:
# 5

# %%
large_random_set.discard(55)
